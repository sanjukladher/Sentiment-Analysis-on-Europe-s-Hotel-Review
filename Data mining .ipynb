# %%
import numpy as np 
import pandas as pd
import nltk
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 50, 18
rcParams["axes.labelsize"] = 16
from pandas import datetime
from matplotlib import pyplot
import seaborn as sns

from sklearn.model_selection import train_test_split

Hotel_reviews = pd.read_excel('\\Users\harsh\Downloads\Hotel_Reviews_Label.xlsx')

Hotel_reviews.head(10)
# Out:
#                                        Hotel_Address Review_Date  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...  2017-08-03
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...  2017-08-03
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...  2017-08-03
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...  2017-07-31
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...  2017-07-31
# 5   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...  2017-07-31
# 6   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...  2017-07-31
# 7   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...  2017-07-24
# 8   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...  2017-07-24
# 9   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...  2017-07-24
#
#    Average_Score   Hotel_Name Reviewer_Nationality  \
# 0            7.7  Hotel Arena              Russia
# 1            7.7  Hotel Arena              Russia
# 2            7.7  Hotel Arena             Ireland
# ...

# %%
#y=Hotel_reviews.Label
#Hotel_reviews=Hotel_reviews.drop(['Label'],axis=1)
Hotel_reviews.shape
# Out:
# (862168, 9)

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(
     Hotel_reviews.Review, y, test_size=0.33, random_state=10000)
X_train.shape
# Out:
# (577652,)

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer(analyzer='word',stop_words="english",lowercase=True,max_features=1000,token_pattern=r'\b[a-zA-Z]{4,10}\b')
X_train_counts = count_vect.fit_transform(X_train.astype('U'))
X_train_counts.shape
# Out:
# (577652, 1000)

# %%
count_vect.get_feature_names()
# Out:
# ['able',
#  'absolutely',
#  'acceptable',
#  'access',
#  'accessible',
#  'account',
#  'actually',
#  'added',
#  'addition',
#  'additional',
#  'adequate',
#  'adults',
#  'advance',
#  'advertised',
#  'afternoon',
#  'aircon',
#  'airport',
#  'alarm',
#  'albert',
#  'allowed',
#  'amazing',
#  'ambiance',
#  'ambience',
#  'amenities',
#  'amsterdam',
#  'annoying',
#  'answer',
#  'apart',
#  'apartment',
#  'appointed',
#  'area',
#  'areas',
#  'arena',
#  'arranged',
#  'arrival',
#  'arrive',
#  'arrived',
#  'arriving',
#  'asked',
#  'asking',
#  'atmosphere',
#  'attention',
#  'attentive',
#  'attitude',
#  'available',
#  'average',
#  'avoid',
#  'aware',
#  'away',
#  'awesome',
#  'awful',
#  'baby',
#  'bacon',
#  'badly',
#  'bags',
#  'balcony',
#  'bank',
#  'barcelona',
#  'barely',
#  'bars',
#  'basement',
#  'basic',
#  'bath',
#  'bathroom',
#  'bathrooms',
#  'bathtub',
#  'beach',
#  'beautiful',
#  'bedding',
#  'bedroom',
#  'bedrooms',
#  'beds',
# ...

# %%
from sklearn.feature_extraction.text import TfidfTransformer,TfidfVectorizer
tfidf_transformer = TfidfTransformer()
tfidf = tfidf_transformer.fit_transform(X_train_counts)
tfidf.shape
# Out:
# (577652, 1000)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
clf = MultinomialNB()
clf1= RandomForestClassifier(max_depth=5, random_state=0)

# %%
print("Train and Test Data Size",X_train.shape,X_test.shape)
print("TF-IDF Data Size",tfidf.shape)
# Out:
# Train and Test Data Size (577652,) (284516,)
# TF-IDF Data Size (577652, 1000)

# %%
#testdata
test=count_vect.transform(X_test.astype('U'))
test.shape
# Out:
# (284516, 1000)

# %%
#Navie Bayes Algorithim
clf_fit=clf.fit(tfidf,Y_train)
#just passing same data to check accuracy on same
print(clf_fit.score(tfidf,Y_train))
#Predict
predict=clf_fit.predict(test)
#Accuracy
np.mean(predict==Y_test)
# Out:
# 0.8600126027435203
# 0.8639268090371016

# %%
#Random Forest
clf_fit_1=clf1.fit(tfidf,Y_train)
#just passing same data to check accuracy on same
print(clf_fit_1.score(tfidf,Y_train))
#Predict
predict=clf_fit_1.predict(test)
#Accuracy
np.mean(predict==Y_test)
# Out:
# 0.8272350827141601
# 0.8206005989118362
